# %%
from generating_text import *
from training_loop import *

model = load_model_from_checkpoint('../data/TinyStoriesV2-GPT4-checkpoint/params.pkl', '../data/TinyStoriesV2-GPT4-checkpoint/checkpoint_iter_26000.pt')
tiny_story_bpe_info = pickle.load(open('../data/TinyStoriesV2-GPT4-bpe_data.pkl', 'rb'))
tiny_story_tokenizer = Tokenizer(*tiny_story_bpe_info)
text_generator = TextGenerator(model, tiny_story_tokenizer)
prompt = "Once upon a time"
generated_text = text_generator.generate(prompt, max_length=200, temperature=1.0, top_k=50)
print(generated_text)
# Out:
# Once upon a time, there was a little boy named Tim. Tim liked to go outside and play with his ball. One day, while Tim was playing, he saw a small flame in the grass. He knew it was not a toy, so he wanted to protect it.
# Tim called all his mom, and she came running with a cup of water. "Don't touch this flame, Tim!" she said. Tim didn't touch the flame, but he was safe, so he looked at the water and thought about how he helped out.
# Tim knew someone was right, so he decided to be a brave knight. He talked to his mom, who was very kind too. "Can I help?" Tim asked his mom, and she let him touch the flame. He felt proud, and his mom was proud of him.
# The moral of the story is: He learned that being brave is important, but being brave can make scary things happen.
# <|endoftext|>

# %%
generated_text = text_generator.generate(prompt, max_length=200, temperature=3, top_k=10)
print(generated_text)
# Out:
# Once upon a time, there was a wealthy woman living in the small hut, with an enormous tree around him. She lived near and every summer, the house and his home. The woman had a pet shop where she liked to feed him food. Every night the woman would give the littlest food for his meal.
# One night in the big city and a small village. Everyone came out of his village to welcome his food and they said that they would be able to get some delicious fruits for everyone they loved in the little village!
# That night the woman cooked some sweet fruit from a nearby hut and invited the woman into his house. They ate their meal together, and they talked to the little village every night to get their tasty food for them. Everyone loved the food and was so thankful and grateful for the little village who saved their land. This story is how we all have to be generous and generous to our people. Everyone was grateful when they saw a delicious fruits, and everyone enjoyed
